# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

import numpy as np
import os, json, cv2, random
import matplotlib.pyplot as plt

from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.utils.visualizer import Visualizer, ColorMode

# %%
from detectron2.data.datasets import register_coco_instances

register_coco_instances("my_dataset_train", {}, "./detectron2/data/coco_json/train/images/train.json", "./detectron2/data/coco_json/train/images/")
register_coco_instances("my_dataset_val", {}, "./detectron2/data/coco_json/val/images/val.json", "./detectron2/data/coco_json/val/images/")
register_coco_instances("my_dataset_test", {}, "./detectron2/data/coco_json/test/images/test.json", "./detectron2/data/coco_json/test/images/")

# %%
train_metadata = MetadataCatalog.get("my_dataset_train")
train_dataset_dicts = DatasetCatalog.get("my_dataset_train")

val_metadata = MetadataCatalog.get("my_dataset_val")
val_dataset_dicts = DatasetCatalog.get("my_dataset_val")

test_metadata = MetadataCatalog.get("my_dataset_test")
test_dataset_dicts = DatasetCatalog.get("my_dataset_test")
# Out:
# WARNING [07/29 19:07:48 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 19:07:48 d2.data.datasets.coco]: Loaded 20 images in COCO format from ./detectron2/data/coco_json/train/images/train.json
# WARNING [07/29 19:07:48 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 19:07:48 d2.data.datasets.coco]: Loaded 5 images in COCO format from ./detectron2/data/coco_json/val/images/val.json
# WARNING [07/29 19:07:48 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 19:07:48 d2.data.datasets.coco]: Loaded 10 images in COCO format from ./detectron2/data/coco_json/test/images/test.json

# %%
for d in random.sample(train_dataset_dicts, 2):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=train_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    plt.imshow(vis.get_image()[:, :, ::-1])
    plt.show()

# %%
from detectron2.engine import DefaultTrainer

cfg = get_cfg()
cfg.OUTPUT_DIR = "./models/Detectron2_Models_infused"
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("my_dataset_train", "my_dataset_val")
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2  # This is the real "batch size" commonly known to deep learning people
cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
cfg.SOLVER.MAX_ITER = 2000    # 1000 iterations seems good enough for this dataset
cfg.SOLVER.STEPS = []        # do not decay learning rate
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 256   # Default is 512, using 256 for this dataset.
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1 
# NOTE: this config means the number of classes, without the background. Do not use num_classes+1 here.

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) #Create an instance of of DefaultTrainer with the given congiguration
trainer.resume_or_load(resume=False) #Load a pretrained model if available (resume training) or start training from scratch if no pretrained model is available
# Out:
# [07/29 19:08:32 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# WARNING [07/29 19:08:32 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 19:08:32 d2.data.datasets.coco]: Loaded 20 images in COCO format from ./detectron2/data/coco_json/train/images/train.json
# WARNING [07/29 19:08:32 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 19:08:32 d2.data.datasets.coco]: Loaded 5 images in COCO format from ./detectron2/data/coco_json/val/images/val.json
# [07/29 19:08:32 d2.data.build]: Removed 0 images with no usable annotations. 25 images left.
# [07/29 19:08:32 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [07/29 19:08:32 d2.data.build]: Using training sampler TrainingSampler
# [07/29 19:08:32 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/29 19:08:32 d2.data.common]: Serializing 25 elements to byte tensors and concatenating them all ...
# [07/29 19:08:32 d2.data.common]: Serialized dataset takes 0.04 MiB
# [07/29 19:08:32 d2.data.build]: Making batched data loader with batch_size=2
# [07/29 19:08:32 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (2, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (1, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (1,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}

# %%
trainer.train()
# Out:
# [07/29 19:08:36 d2.engine.train_loop]: Starting training from iteration 0
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [07/29 19:08:46 d2.utils.events]:  eta: 0:11:28  iter: 19  total_loss: 1.753  loss_cls: 0.7974  loss_box_reg: 0.118  loss_mask: 0.6923  loss_rpn_cls: 0.1484  loss_rpn_loc: 0.01191    time: 0.3413  last_time: 0.2669  data_time: 0.0148  last_data_time: 0.0034   lr: 4.9953e-06  max_mem: 2046M
# [07/29 19:08:52 d2.utils.events]:  eta: 0:11:15  iter: 39  total_loss: 1.665  loss_cls: 0.5993  loss_box_reg: 0.1197  loss_mask: 0.6883  loss_rpn_cls: 0.1947  loss_rpn_loc: 0.02562    time: 0.3334  last_time: 0.3452  data_time: 0.0035  last_data_time: 0.0049   lr: 9.9902e-06  max_mem: 2048M
# [07/29 19:08:59 d2.utils.events]:  eta: 0:10:44  iter: 59  total_loss: 1.318  loss_cls: 0.3497  loss_box_reg: 0.1079  loss_mask: 0.6793  loss_rpn_cls: 0.1014  loss_rpn_loc: 0.01527    time: 0.3299  last_time: 0.3552  data_time: 0.0048  last_data_time: 0.0056   lr: 1.4985e-05  max_mem: 2048M
# [07/29 19:09:05 d2.utils.events]:  eta: 0:10:36  iter: 79  total_loss: 0.976  loss_cls: 0.1744  loss_box_reg: 0.0302  loss_mask: 0.6667  loss_rpn_cls: 0.08166  loss_rpn_loc: 0.01915    time: 0.3286  last_time: 0.2648  data_time: 0.0043  last_data_time: 0.0031   lr: 1.998e-05  max_mem: 2048M
# [07/29 19:09:12 d2.utils.events]:  eta: 0:10:30  iter: 99  total_loss: 0.8449  loss_cls: 0.08087  loss_box_reg: 0.009435  loss_mask: 0.65  loss_rpn_cls: 0.0758  loss_rpn_loc: 0.01628    time: 0.3295  last_time: 0.3642  data_time: 0.0057  last_data_time: 0.0054   lr: 2.4975e-05  max_mem: 2048M
# [07/29 19:09:19 d2.utils.events]:  eta: 0:10:24  iter: 119  total_loss: 0.9137  loss_cls: 0.07075  loss_box_reg: 0.02977  loss_mask: 0.6417  loss_rpn_cls: 0.06922  loss_rpn_loc: 0.01959    time: 0.3308  last_time: 0.3726  data_time: 0.0076  last_data_time: 0.0051   lr: 2.997e-05  max_mem: 2048M
# [07/29 19:09:25 d2.utils.events]:  eta: 0:10:17  iter: 139  total_loss: 0.8719  loss_cls: 0.07821  loss_box_reg: 0.05605  loss_mask: 0.6255  loss_rpn_cls: 0.0437  loss_rpn_loc: 0.01891    time: 0.3284  last_time: 0.3056  data_time: 0.0060  last_data_time: 0.0046   lr: 3.4965e-05  max_mem: 2048M
# [07/29 19:09:32 d2.utils.events]:  eta: 0:10:10  iter: 159  total_loss: 0.9321  loss_cls: 0.1146  loss_box_reg: 0.08922  loss_mask: 0.6174  loss_rpn_cls: 0.03236  loss_rpn_loc: 0.01727    time: 0.3283  last_time: 0.2779  data_time: 0.0059  last_data_time: 0.0076   lr: 3.996e-05  max_mem: 2048M
# [07/29 19:09:38 d2.utils.events]:  eta: 0:10:01  iter: 179  total_loss: 0.9468  loss_cls: 0.1359  loss_box_reg: 0.1426  loss_mask: 0.6079  loss_rpn_cls: 0.03684  loss_rpn_loc: 0.01925    time: 0.3262  last_time: 0.3059  data_time: 0.0050  last_data_time: 0.0049   lr: 4.4955e-05  max_mem: 2048M
# [07/29 19:09:44 d2.utils.events]:  eta: 0:09:52  iter: 199  total_loss: 0.9632  loss_cls: 0.1457  loss_box_reg: 0.168  loss_mask: 0.5742  loss_rpn_cls: 0.02259  loss_rpn_loc: 0.01845    time: 0.3255  last_time: 0.2953  data_time: 0.0047  last_data_time: 0.0047   lr: 4.995e-05  max_mem: 2048M
# [07/29 19:09:51 d2.utils.events]:  eta: 0:09:49  iter: 219  total_loss: 1.036  loss_cls: 0.1781  loss_box_reg: 0.2036  loss_mask: 0.561  loss_rpn_cls: 0.01834  loss_rpn_loc: 0.01103    time: 0.3261  last_time: 0.3349  data_time: 0.0056  last_data_time: 0.0046   lr: 5.4945e-05  max_mem: 2048M
# [07/29 19:09:58 d2.utils.events]:  eta: 0:09:43  iter: 239  total_loss: 0.9962  loss_cls: 0.1485  loss_box_reg: 0.1834  loss_mask: 0.5689  loss_rpn_cls: 0.0235  loss_rpn_loc: 0.01218    time: 0.3269  last_time: 0.3775  data_time: 0.0055  last_data_time: 0.0051   lr: 5.994e-05  max_mem: 2048M
# [07/29 19:10:04 d2.utils.events]:  eta: 0:09:37  iter: 259  total_loss: 1.018  loss_cls: 0.1506  loss_box_reg: 0.2154  loss_mask: 0.5434  loss_rpn_cls: 0.01324  loss_rpn_loc: 0.01083    time: 0.3272  last_time: 0.3145  data_time: 0.0069  last_data_time: 0.0052   lr: 6.4935e-05  max_mem: 2048M
# [07/29 19:10:11 d2.utils.events]:  eta: 0:09:29  iter: 279  total_loss: 0.948  loss_cls: 0.1335  loss_box_reg: 0.205  loss_mask: 0.5212  loss_rpn_cls: 0.01643  loss_rpn_loc: 0.01157    time: 0.3273  last_time: 0.3687  data_time: 0.0048  last_data_time: 0.0053   lr: 6.993e-05  max_mem: 2048M
# [07/29 19:10:17 d2.utils.events]:  eta: 0:09:22  iter: 299  total_loss: 0.9634  loss_cls: 0.1462  loss_box_reg: 0.2246  loss_mask: 0.5163  loss_rpn_cls: 0.01899  loss_rpn_loc: 0.01034    time: 0.3273  last_time: 0.3110  data_time: 0.0050  last_data_time: 0.0047   lr: 7.4925e-05  max_mem: 2048M
# [07/29 19:10:24 d2.utils.events]:  eta: 0:09:16  iter: 319  total_loss: 0.9467  loss_cls: 0.1343  loss_box_reg: 0.2095  loss_mask: 0.4879  loss_rpn_cls: 0.01275  loss_rpn_loc: 0.0111    time: 0.3277  last_time: 0.3678  data_time: 0.0061  last_data_time: 0.0051   lr: 7.992e-05  max_mem: 2048M
# [07/29 19:10:31 d2.utils.events]:  eta: 0:09:11  iter: 339  total_loss: 0.8792  loss_cls: 0.1387  loss_box_reg: 0.2521  loss_mask: 0.4652  loss_rpn_cls: 0.01119  loss_rpn_loc: 0.01278    time: 0.3286  last_time: 0.3678  data_time: 0.0046  last_data_time: 0.0051   lr: 8.4915e-05  max_mem: 2048M
# [07/29 19:10:38 d2.utils.events]:  eta: 0:09:05  iter: 359  total_loss: 0.8796  loss_cls: 0.13  loss_box_reg: 0.2356  loss_mask: 0.456  loss_rpn_cls: 0.00643  loss_rpn_loc: 0.007926    time: 0.3297  last_time: 0.2708  data_time: 0.0046  last_data_time: 0.0042   lr: 8.991e-05  max_mem: 2048M
# [07/29 19:10:44 d2.utils.events]:  eta: 0:09:00  iter: 379  total_loss: 0.895  loss_cls: 0.1345  loss_box_reg: 0.2323  loss_mask: 0.438  loss_rpn_cls: 0.009429  loss_rpn_loc: 0.009476    time: 0.3298  last_time: 0.3680  data_time: 0.0044  last_data_time: 0.0036   lr: 9.4905e-05  max_mem: 2048M
# [07/29 19:10:51 d2.utils.events]:  eta: 0:08:54  iter: 399  total_loss: 0.9034  loss_cls: 0.1303  loss_box_reg: 0.242  loss_mask: 0.4211  loss_rpn_cls: 0.01124  loss_rpn_loc: 0.02627    time: 0.3302  last_time: 0.3036  data_time: 0.0048  last_data_time: 0.0051   lr: 9.99e-05  max_mem: 2048M
# [07/29 19:10:58 d2.utils.events]:  eta: 0:08:47  iter: 419  total_loss: 0.8909  loss_cls: 0.1257  loss_box_reg: 0.271  loss_mask: 0.385  loss_rpn_cls: 0.01195  loss_rpn_loc: 0.01059    time: 0.3308  last_time: 0.3175  data_time: 0.0044  last_data_time: 0.0036   lr: 0.0001049  max_mem: 2048M
# [07/29 19:11:05 d2.utils.events]:  eta: 0:08:40  iter: 439  total_loss: 0.8379  loss_cls: 0.1031  loss_box_reg: 0.2305  loss_mask: 0.401  loss_rpn_cls: 0.006257  loss_rpn_loc: 0.009914    time: 0.3305  last_time: 0.3644  data_time: 0.0052  last_data_time: 0.0050   lr: 0.00010989  max_mem: 2048M
# [07/29 19:11:11 d2.utils.events]:  eta: 0:08:35  iter: 459  total_loss: 0.7922  loss_cls: 0.1064  loss_box_reg: 0.2436  loss_mask: 0.3853  loss_rpn_cls: 0.004843  loss_rpn_loc: 0.006475    time: 0.3311  last_time: 0.3357  data_time: 0.0054  last_data_time: 0.0035   lr: 0.00011489  max_mem: 2048M
# [07/29 19:11:18 d2.utils.events]:  eta: 0:08:28  iter: 479  total_loss: 0.7505  loss_cls: 0.1149  loss_box_reg: 0.2594  loss_mask: 0.3789  loss_rpn_cls: 0.00628  loss_rpn_loc: 0.007    time: 0.3309  last_time: 0.2819  data_time: 0.0040  last_data_time: 0.0036   lr: 0.00011988  max_mem: 2048M
# [07/29 19:11:25 d2.utils.events]:  eta: 0:08:21  iter: 499  total_loss: 0.7808  loss_cls: 0.1052  loss_box_reg: 0.2196  loss_mask: 0.3634  loss_rpn_cls: 0.007556  loss_rpn_loc: 0.008785    time: 0.3312  last_time: 0.3341  data_time: 0.0044  last_data_time: 0.0034   lr: 0.00012488  max_mem: 2048M
# [07/29 19:11:31 d2.utils.events]:  eta: 0:08:14  iter: 519  total_loss: 0.7296  loss_cls: 0.09701  loss_box_reg: 0.2369  loss_mask: 0.3562  loss_rpn_cls: 0.004059  loss_rpn_loc: 0.007091    time: 0.3312  last_time: 0.2917  data_time: 0.0051  last_data_time: 0.0033   lr: 0.00012987  max_mem: 2048M
# [07/29 19:11:38 d2.utils.events]:  eta: 0:08:07  iter: 539  total_loss: 0.6874  loss_cls: 0.08866  loss_box_reg: 0.2247  loss_mask: 0.3377  loss_rpn_cls: 0.002792  loss_rpn_loc: 0.007196    time: 0.3310  last_time: 0.3132  data_time: 0.0039  last_data_time: 0.0053   lr: 0.00013487  max_mem: 2048M
# [07/29 19:11:45 d2.utils.events]:  eta: 0:08:02  iter: 559  total_loss: 0.6711  loss_cls: 0.08392  loss_box_reg: 0.227  loss_mask: 0.3121  loss_rpn_cls: 0.003108  loss_rpn_loc: 0.01369    time: 0.3316  last_time: 0.3422  data_time: 0.0047  last_data_time: 0.0032   lr: 0.00013986  max_mem: 2048M
# [07/29 19:11:52 d2.utils.events]:  eta: 0:07:56  iter: 579  total_loss: 0.6553  loss_cls: 0.07227  loss_box_reg: 0.2013  loss_mask: 0.3287  loss_rpn_cls: 0.004003  loss_rpn_loc: 0.007886    time: 0.3319  last_time: 0.3386  data_time: 0.0046  last_data_time: 0.0033   lr: 0.00014486  max_mem: 2048M
# [07/29 19:11:58 d2.utils.events]:  eta: 0:07:49  iter: 599  total_loss: 0.6511  loss_cls: 0.08251  loss_box_reg: 0.1942  loss_mask: 0.3182  loss_rpn_cls: 0.00592  loss_rpn_loc: 0.005953    time: 0.3316  last_time: 0.3234  data_time: 0.0040  last_data_time: 0.0049   lr: 0.00014985  max_mem: 2048M
# [07/29 19:12:05 d2.utils.events]:  eta: 0:07:43  iter: 619  total_loss: 0.6537  loss_cls: 0.07815  loss_box_reg: 0.1919  loss_mask: 0.2994  loss_rpn_cls: 0.00403  loss_rpn_loc: 0.007699    time: 0.3320  last_time: 0.3663  data_time: 0.0057  last_data_time: 0.0039   lr: 0.00015485  max_mem: 2048M
# [07/29 19:12:12 d2.utils.events]:  eta: 0:07:36  iter: 639  total_loss: 0.5144  loss_cls: 0.05207  loss_box_reg: 0.1624  loss_mask: 0.2778  loss_rpn_cls: 0.0004472  loss_rpn_loc: 0.004734    time: 0.3320  last_time: 0.3761  data_time: 0.0044  last_data_time: 0.0032   lr: 0.00015984  max_mem: 2048M
# [07/29 19:12:19 d2.utils.events]:  eta: 0:07:29  iter: 659  total_loss: 0.5101  loss_cls: 0.06004  loss_box_reg: 0.1456  loss_mask: 0.2816  loss_rpn_cls: 0.002719  loss_rpn_loc: 0.00489    time: 0.3322  last_time: 0.3709  data_time: 0.0043  last_data_time: 0.0046   lr: 0.00016484  max_mem: 2048M
# [07/29 19:12:25 d2.utils.events]:  eta: 0:07:23  iter: 679  total_loss: 0.5182  loss_cls: 0.05427  loss_box_reg: 0.1406  loss_mask: 0.2688  loss_rpn_cls: 0.003616  loss_rpn_loc: 0.007406    time: 0.3324  last_time: 0.2805  data_time: 0.0044  last_data_time: 0.0033   lr: 0.00016983  max_mem: 2048M
# [07/29 19:12:32 d2.utils.events]:  eta: 0:07:16  iter: 699  total_loss: 0.4769  loss_cls: 0.05954  loss_box_reg: 0.1406  loss_mask: 0.2611  loss_rpn_cls: 0.01499  loss_rpn_loc: 0.008386    time: 0.3323  last_time: 0.3422  data_time: 0.0036  last_data_time: 0.0050   lr: 0.00017483  max_mem: 2048M
# [07/29 19:12:38 d2.utils.events]:  eta: 0:07:09  iter: 719  total_loss: 0.4469  loss_cls: 0.05319  loss_box_reg: 0.1253  loss_mask: 0.2392  loss_rpn_cls: 0.0003907  loss_rpn_loc: 0.005777    time: 0.3321  last_time: 0.3882  data_time: 0.0056  last_data_time: 0.0049   lr: 0.00017982  max_mem: 2048M
# [07/29 19:12:45 d2.utils.events]:  eta: 0:07:03  iter: 739  total_loss: 0.465  loss_cls: 0.05514  loss_box_reg: 0.1476  loss_mask: 0.2433  loss_rpn_cls: 0.0006569  loss_rpn_loc: 0.005011    time: 0.3323  last_time: 0.3681  data_time: 0.0044  last_data_time: 0.0035   lr: 0.00018482  max_mem: 2048M
# [07/29 19:12:52 d2.utils.events]:  eta: 0:06:56  iter: 759  total_loss: 0.4277  loss_cls: 0.05072  loss_box_reg: 0.1149  loss_mask: 0.2326  loss_rpn_cls: 0.0007612  loss_rpn_loc: 0.004675    time: 0.3321  last_time: 0.3076  data_time: 0.0036  last_data_time: 0.0046   lr: 0.00018981  max_mem: 2048M
# [07/29 19:12:59 d2.utils.events]:  eta: 0:06:49  iter: 779  total_loss: 0.3792  loss_cls: 0.04189  loss_box_reg: 0.1126  loss_mask: 0.203  loss_rpn_cls: 0.002849  loss_rpn_loc: 0.005128    time: 0.3324  last_time: 0.3944  data_time: 0.0061  last_data_time: 0.0046   lr: 0.00019481  max_mem: 2048M
# [07/29 19:13:05 d2.utils.events]:  eta: 0:06:42  iter: 799  total_loss: 0.4193  loss_cls: 0.04938  loss_box_reg: 0.1104  loss_mask: 0.2213  loss_rpn_cls: 0.001858  loss_rpn_loc: 0.03529    time: 0.3322  last_time: 0.2893  data_time: 0.0045  last_data_time: 0.0033   lr: 0.0001998  max_mem: 2048M
# [07/29 19:13:12 d2.utils.events]:  eta: 0:06:36  iter: 819  total_loss: 0.3704  loss_cls: 0.052  loss_box_reg: 0.1161  loss_mask: 0.1939  loss_rpn_cls: 0.0004531  loss_rpn_loc: 0.004119    time: 0.3325  last_time: 0.3346  data_time: 0.0057  last_data_time: 0.0030   lr: 0.0002048  max_mem: 2048M
# [07/29 19:13:19 d2.utils.events]:  eta: 0:06:29  iter: 839  total_loss: 0.3366  loss_cls: 0.04478  loss_box_reg: 0.09945  loss_mask: 0.1791  loss_rpn_cls: 0.0003315  loss_rpn_loc: 0.005036    time: 0.3328  last_time: 0.3494  data_time: 0.0040  last_data_time: 0.0050   lr: 0.00020979  max_mem: 2048M
# [07/29 19:13:26 d2.utils.events]:  eta: 0:06:23  iter: 859  total_loss: 0.3225  loss_cls: 0.03743  loss_box_reg: 0.1027  loss_mask: 0.1843  loss_rpn_cls: 0.0005253  loss_rpn_loc: 0.003464    time: 0.3330  last_time: 0.3316  data_time: 0.0055  last_data_time: 0.0037   lr: 0.00021479  max_mem: 2048M
# [07/29 19:13:33 d2.utils.events]:  eta: 0:06:17  iter: 879  total_loss: 0.3245  loss_cls: 0.03444  loss_box_reg: 0.09504  loss_mask: 0.1925  loss_rpn_cls: 0.001866  loss_rpn_loc: 0.005352    time: 0.3334  last_time: 0.3987  data_time: 0.0053  last_data_time: 0.0051   lr: 0.00021978  max_mem: 2048M
# [07/29 19:13:39 d2.utils.events]:  eta: 0:06:09  iter: 899  total_loss: 0.3282  loss_cls: 0.039  loss_box_reg: 0.09314  loss_mask: 0.1782  loss_rpn_cls: 6.794e-05  loss_rpn_loc: 0.003132    time: 0.3332  last_time: 0.3228  data_time: 0.0047  last_data_time: 0.0064   lr: 0.00022478  max_mem: 2048M
# [07/29 19:13:46 d2.utils.events]:  eta: 0:06:03  iter: 919  total_loss: 0.3551  loss_cls: 0.03907  loss_box_reg: 0.09391  loss_mask: 0.1913  loss_rpn_cls: 0.0005454  loss_rpn_loc: 0.005458    time: 0.3333  last_time: 0.3960  data_time: 0.0046  last_data_time: 0.0034   lr: 0.00022977  max_mem: 2048M
# [07/29 19:13:53 d2.utils.events]:  eta: 0:05:57  iter: 939  total_loss: 0.3114  loss_cls: 0.03608  loss_box_reg: 0.09041  loss_mask: 0.1774  loss_rpn_cls: 0.0002165  loss_rpn_loc: 0.004091    time: 0.3335  last_time: 0.2943  data_time: 0.0043  last_data_time: 0.0038   lr: 0.00023477  max_mem: 2048M
# [07/29 19:14:00 d2.utils.events]:  eta: 0:05:50  iter: 959  total_loss: 0.3418  loss_cls: 0.03812  loss_box_reg: 0.09552  loss_mask: 0.1897  loss_rpn_cls: 0.0008409  loss_rpn_loc: 0.004121    time: 0.3337  last_time: 0.2816  data_time: 0.0047  last_data_time: 0.0036   lr: 0.00023976  max_mem: 2048M
# [07/29 19:14:07 d2.utils.events]:  eta: 0:05:44  iter: 979  total_loss: 0.2817  loss_cls: 0.03122  loss_box_reg: 0.08864  loss_mask: 0.1672  loss_rpn_cls: 0.0001715  loss_rpn_loc: 0.002849    time: 0.3344  last_time: 0.3161  data_time: 0.0057  last_data_time: 0.0094   lr: 0.00024476  max_mem: 2048M
# [07/29 19:14:14 d2.utils.events]:  eta: 0:05:37  iter: 999  total_loss: 0.2735  loss_cls: 0.03208  loss_box_reg: 0.09026  loss_mask: 0.1529  loss_rpn_cls: 0.0004017  loss_rpn_loc: 0.003897    time: 0.3345  last_time: 0.3867  data_time: 0.0060  last_data_time: 0.0057   lr: 0.00024975  max_mem: 2048M
# [07/29 19:14:21 d2.utils.events]:  eta: 0:05:30  iter: 1019  total_loss: 0.2944  loss_cls: 0.03968  loss_box_reg: 0.08613  loss_mask: 0.1577  loss_rpn_cls: 0.0004362  loss_rpn_loc: 0.005169    time: 0.3347  last_time: 0.3987  data_time: 0.0052  last_data_time: 0.0031   lr: 0.00025  max_mem: 2048M
# [07/29 19:14:28 d2.utils.events]:  eta: 0:05:23  iter: 1039  total_loss: 0.2979  loss_cls: 0.03645  loss_box_reg: 0.0869  loss_mask: 0.1674  loss_rpn_cls: 0.001428  loss_rpn_loc: 0.005094    time: 0.3346  last_time: 0.3360  data_time: 0.0038  last_data_time: 0.0045   lr: 0.00025  max_mem: 2048M
# [07/29 19:14:34 d2.utils.events]:  eta: 0:05:17  iter: 1059  total_loss: 0.3218  loss_cls: 0.03587  loss_box_reg: 0.08712  loss_mask: 0.1709  loss_rpn_cls: 0.0008574  loss_rpn_loc: 0.007636    time: 0.3347  last_time: 0.3832  data_time: 0.0052  last_data_time: 0.0063   lr: 0.00025  max_mem: 2048M
# [07/29 19:14:41 d2.utils.events]:  eta: 0:05:11  iter: 1079  total_loss: 0.2686  loss_cls: 0.03595  loss_box_reg: 0.07593  loss_mask: 0.1537  loss_rpn_cls: 0.0003715  loss_rpn_loc: 0.005396    time: 0.3347  last_time: 0.3495  data_time: 0.0066  last_data_time: 0.0032   lr: 0.00025  max_mem: 2048M
# [07/29 19:14:48 d2.utils.events]:  eta: 0:05:04  iter: 1099  total_loss: 0.2742  loss_cls: 0.02753  loss_box_reg: 0.0837  loss_mask: 0.1552  loss_rpn_cls: 6.95e-05  loss_rpn_loc: 0.002582    time: 0.3350  last_time: 0.3752  data_time: 0.0041  last_data_time: 0.0042   lr: 0.00025  max_mem: 2048M
# [07/29 19:14:55 d2.utils.events]:  eta: 0:04:57  iter: 1119  total_loss: 0.2929  loss_cls: 0.03118  loss_box_reg: 0.07745  loss_mask: 0.1662  loss_rpn_cls: 0.0004395  loss_rpn_loc: 0.004601    time: 0.3351  last_time: 0.2610  data_time: 0.0055  last_data_time: 0.0031   lr: 0.00025  max_mem: 2048M
# [07/29 19:15:02 d2.utils.events]:  eta: 0:04:51  iter: 1139  total_loss: 0.2398  loss_cls: 0.0281  loss_box_reg: 0.07682  loss_mask: 0.145  loss_rpn_cls: 5.504e-05  loss_rpn_loc: 0.003405    time: 0.3354  last_time: 0.3702  data_time: 0.0049  last_data_time: 0.0033   lr: 0.00025  max_mem: 2048M
# [07/29 19:15:09 d2.utils.events]:  eta: 0:04:45  iter: 1159  total_loss: 0.2417  loss_cls: 0.02686  loss_box_reg: 0.06667  loss_mask: 0.1372  loss_rpn_cls: 0.0003009  loss_rpn_loc: 0.002853    time: 0.3355  last_time: 0.3255  data_time: 0.0041  last_data_time: 0.0048   lr: 0.00025  max_mem: 2048M
# [07/29 19:15:16 d2.utils.events]:  eta: 0:04:39  iter: 1179  total_loss: 0.2407  loss_cls: 0.03322  loss_box_reg: 0.07941  loss_mask: 0.1341  loss_rpn_cls: 0.0002013  loss_rpn_loc: 0.004567    time: 0.3356  last_time: 0.3469  data_time: 0.0045  last_data_time: 0.0034   lr: 0.00025  max_mem: 2048M
# [07/29 19:15:22 d2.utils.events]:  eta: 0:04:33  iter: 1199  total_loss: 0.2094  loss_cls: 0.02233  loss_box_reg: 0.05907  loss_mask: 0.1277  loss_rpn_cls: 0.0003799  loss_rpn_loc: 0.003688    time: 0.3357  last_time: 0.2712  data_time: 0.0039  last_data_time: 0.0050   lr: 0.00025  max_mem: 2048M
# [07/29 19:15:30 d2.utils.events]:  eta: 0:04:27  iter: 1219  total_loss: 0.2339  loss_cls: 0.03013  loss_box_reg: 0.06877  loss_mask: 0.1343  loss_rpn_cls: 0.000852  loss_rpn_loc: 0.004692    time: 0.3360  last_time: 0.4281  data_time: 0.0067  last_data_time: 0.0047   lr: 0.00025  max_mem: 2048M
# [07/29 19:15:36 d2.utils.events]:  eta: 0:04:20  iter: 1239  total_loss: 0.2212  loss_cls: 0.03033  loss_box_reg: 0.06534  loss_mask: 0.1286  loss_rpn_cls: 0.0005212  loss_rpn_loc: 0.005536    time: 0.3361  last_time: 0.3500  data_time: 0.0047  last_data_time: 0.0051   lr: 0.00025  max_mem: 2048M
# [07/29 19:15:43 d2.utils.events]:  eta: 0:04:13  iter: 1259  total_loss: 0.2124  loss_cls: 0.02247  loss_box_reg: 0.05624  loss_mask: 0.1271  loss_rpn_cls: 7.776e-05  loss_rpn_loc: 0.005991    time: 0.3362  last_time: 0.3211  data_time: 0.0045  last_data_time: 0.0038   lr: 0.00025  max_mem: 2048M
# [07/29 19:15:50 d2.utils.events]:  eta: 0:04:06  iter: 1279  total_loss: 0.1921  loss_cls: 0.02557  loss_box_reg: 0.05256  loss_mask: 0.1164  loss_rpn_cls: 0.0001866  loss_rpn_loc: 0.002231    time: 0.3363  last_time: 0.3706  data_time: 0.0048  last_data_time: 0.0033   lr: 0.00025  max_mem: 2048M
# [07/29 19:15:58 d2.utils.events]:  eta: 0:04:00  iter: 1299  total_loss: 0.2228  loss_cls: 0.02582  loss_box_reg: 0.06788  loss_mask: 0.1275  loss_rpn_cls: 0.0007103  loss_rpn_loc: 0.005404    time: 0.3368  last_time: 0.3798  data_time: 0.0049  last_data_time: 0.0054   lr: 0.00025  max_mem: 2048M
# [07/29 19:16:05 d2.utils.events]:  eta: 0:03:54  iter: 1319  total_loss: 0.2098  loss_cls: 0.02473  loss_box_reg: 0.06227  loss_mask: 0.1275  loss_rpn_cls: 3.58e-05  loss_rpn_loc: 0.002792    time: 0.3373  last_time: 0.3108  data_time: 0.0058  last_data_time: 0.0034   lr: 0.00025  max_mem: 2048M
# [07/29 19:16:12 d2.utils.events]:  eta: 0:03:47  iter: 1339  total_loss: 0.2235  loss_cls: 0.03038  loss_box_reg: 0.07238  loss_mask: 0.1306  loss_rpn_cls: 0.0002365  loss_rpn_loc: 0.003402    time: 0.3374  last_time: 0.3878  data_time: 0.0056  last_data_time: 0.0046   lr: 0.00025  max_mem: 2048M
# [07/29 19:16:19 d2.utils.events]:  eta: 0:03:40  iter: 1359  total_loss: 0.2235  loss_cls: 0.02224  loss_box_reg: 0.06585  loss_mask: 0.1216  loss_rpn_cls: 0.0001048  loss_rpn_loc: 0.004303    time: 0.3376  last_time: 0.3886  data_time: 0.0055  last_data_time: 0.0050   lr: 0.00025  max_mem: 2048M
# [07/29 19:16:26 d2.utils.events]:  eta: 0:03:33  iter: 1379  total_loss: 0.1982  loss_cls: 0.02777  loss_box_reg: 0.06472  loss_mask: 0.1115  loss_rpn_cls: 0.0004974  loss_rpn_loc: 0.003108    time: 0.3377  last_time: 0.3810  data_time: 0.0048  last_data_time: 0.0053   lr: 0.00025  max_mem: 2048M
# [07/29 19:16:33 d2.utils.events]:  eta: 0:03:26  iter: 1399  total_loss: 0.2238  loss_cls: 0.03071  loss_box_reg: 0.06983  loss_mask: 0.1135  loss_rpn_cls: 0.002006  loss_rpn_loc: 0.004089    time: 0.3380  last_time: 0.3467  data_time: 0.0047  last_data_time: 0.0050   lr: 0.00025  max_mem: 2048M
# [07/29 19:16:40 d2.utils.events]:  eta: 0:03:20  iter: 1419  total_loss: 0.211  loss_cls: 0.02777  loss_box_reg: 0.07465  loss_mask: 0.108  loss_rpn_cls: 0.0003205  loss_rpn_loc: 0.001937    time: 0.3381  last_time: 0.3720  data_time: 0.0053  last_data_time: 0.0037   lr: 0.00025  max_mem: 2048M
# [07/29 19:16:47 d2.utils.events]:  eta: 0:03:13  iter: 1439  total_loss: 0.1925  loss_cls: 0.02055  loss_box_reg: 0.05794  loss_mask: 0.1177  loss_rpn_cls: 0.0001854  loss_rpn_loc: 0.002937    time: 0.3383  last_time: 0.3112  data_time: 0.0050  last_data_time: 0.0050   lr: 0.00025  max_mem: 2048M
# [07/29 19:16:54 d2.utils.events]:  eta: 0:03:06  iter: 1459  total_loss: 0.1957  loss_cls: 0.03013  loss_box_reg: 0.06449  loss_mask: 0.1129  loss_rpn_cls: 0.0002278  loss_rpn_loc: 0.003086    time: 0.3383  last_time: 0.3363  data_time: 0.0046  last_data_time: 0.0056   lr: 0.00025  max_mem: 2048M
# [07/29 19:17:01 d2.utils.events]:  eta: 0:02:59  iter: 1479  total_loss: 0.2166  loss_cls: 0.02481  loss_box_reg: 0.06653  loss_mask: 0.1187  loss_rpn_cls: 0.0003747  loss_rpn_loc: 0.003307    time: 0.3386  last_time: 0.4016  data_time: 0.0056  last_data_time: 0.0047   lr: 0.00025  max_mem: 2048M
# [07/29 19:17:08 d2.utils.events]:  eta: 0:02:52  iter: 1499  total_loss: 0.2295  loss_cls: 0.0316  loss_box_reg: 0.07065  loss_mask: 0.1153  loss_rpn_cls: 0.0003455  loss_rpn_loc: 0.003611    time: 0.3387  last_time: 0.3856  data_time: 0.0047  last_data_time: 0.0052   lr: 0.00025  max_mem: 2048M
# [07/29 19:17:15 d2.utils.events]:  eta: 0:02:46  iter: 1519  total_loss: 0.2018  loss_cls: 0.02656  loss_box_reg: 0.06161  loss_mask: 0.1174  loss_rpn_cls: 0.0008897  loss_rpn_loc: 0.004904    time: 0.3389  last_time: 0.3564  data_time: 0.0054  last_data_time: 0.0038   lr: 0.00025  max_mem: 2048M
# [07/29 19:17:22 d2.utils.events]:  eta: 0:02:39  iter: 1539  total_loss: 0.1921  loss_cls: 0.02691  loss_box_reg: 0.05765  loss_mask: 0.1056  loss_rpn_cls: 4.326e-05  loss_rpn_loc: 0.002576    time: 0.3389  last_time: 0.3471  data_time: 0.0049  last_data_time: 0.0038   lr: 0.00025  max_mem: 2048M
# [07/29 19:17:29 d2.utils.events]:  eta: 0:02:32  iter: 1559  total_loss: 0.1915  loss_cls: 0.02273  loss_box_reg: 0.06029  loss_mask: 0.1049  loss_rpn_cls: 0.0001787  loss_rpn_loc: 0.003257    time: 0.3390  last_time: 0.3915  data_time: 0.0041  last_data_time: 0.0051   lr: 0.00025  max_mem: 2048M
# [07/29 19:17:36 d2.utils.events]:  eta: 0:02:25  iter: 1579  total_loss: 0.202  loss_cls: 0.02897  loss_box_reg: 0.06265  loss_mask: 0.1205  loss_rpn_cls: 0.0001585  loss_rpn_loc: 0.003881    time: 0.3391  last_time: 0.2892  data_time: 0.0044  last_data_time: 0.0035   lr: 0.00025  max_mem: 2048M
# [07/29 19:17:42 d2.utils.events]:  eta: 0:02:18  iter: 1599  total_loss: 0.1551  loss_cls: 0.02  loss_box_reg: 0.04978  loss_mask: 0.09001  loss_rpn_cls: 0.0001172  loss_rpn_loc: 0.002336    time: 0.3392  last_time: 0.3856  data_time: 0.0047  last_data_time: 0.0048   lr: 0.00025  max_mem: 2048M
# [07/29 19:17:50 d2.utils.events]:  eta: 0:02:11  iter: 1619  total_loss: 0.1715  loss_cls: 0.02521  loss_box_reg: 0.05112  loss_mask: 0.09432  loss_rpn_cls: 0.0001206  loss_rpn_loc: 0.00276    time: 0.3395  last_time: 0.3029  data_time: 0.0043  last_data_time: 0.0035   lr: 0.00025  max_mem: 2048M
# [07/29 19:17:57 d2.utils.events]:  eta: 0:02:05  iter: 1639  total_loss: 0.1801  loss_cls: 0.0292  loss_box_reg: 0.0613  loss_mask: 0.09611  loss_rpn_cls: 0.0002089  loss_rpn_loc: 0.003303    time: 0.3397  last_time: 0.3399  data_time: 0.0043  last_data_time: 0.0034   lr: 0.00025  max_mem: 2048M
# [07/29 19:18:04 d2.utils.events]:  eta: 0:01:58  iter: 1659  total_loss: 0.1735  loss_cls: 0.01934  loss_box_reg: 0.04936  loss_mask: 0.09834  loss_rpn_cls: 0.0003033  loss_rpn_loc: 0.004444    time: 0.3398  last_time: 0.3306  data_time: 0.0048  last_data_time: 0.0052   lr: 0.00025  max_mem: 2048M
# [07/29 19:18:11 d2.utils.events]:  eta: 0:01:51  iter: 1679  total_loss: 0.2821  loss_cls: 0.03174  loss_box_reg: 0.05705  loss_mask: 0.1137  loss_rpn_cls: 0.001006  loss_rpn_loc: 0.02157    time: 0.3399  last_time: 0.4057  data_time: 0.0064  last_data_time: 0.0048   lr: 0.00025  max_mem: 2048M
# [07/29 19:18:18 d2.utils.events]:  eta: 0:01:44  iter: 1699  total_loss: 0.1611  loss_cls: 0.02229  loss_box_reg: 0.04714  loss_mask: 0.09506  loss_rpn_cls: 0.0002731  loss_rpn_loc: 0.002862    time: 0.3400  last_time: 0.3467  data_time: 0.0049  last_data_time: 0.0037   lr: 0.00025  max_mem: 2048M
# [07/29 19:18:25 d2.utils.events]:  eta: 0:01:37  iter: 1719  total_loss: 0.1551  loss_cls: 0.02411  loss_box_reg: 0.05221  loss_mask: 0.09204  loss_rpn_cls: 0.0005777  loss_rpn_loc: 0.003668    time: 0.3403  last_time: 0.3797  data_time: 0.0049  last_data_time: 0.0037   lr: 0.00025  max_mem: 2048M
# [07/29 19:18:32 d2.utils.events]:  eta: 0:01:30  iter: 1739  total_loss: 0.1566  loss_cls: 0.01919  loss_box_reg: 0.0449  loss_mask: 0.08876  loss_rpn_cls: 0.0001195  loss_rpn_loc: 0.002388    time: 0.3404  last_time: 0.3903  data_time: 0.0055  last_data_time: 0.0049   lr: 0.00025  max_mem: 2048M
# [07/29 19:18:39 d2.utils.events]:  eta: 0:01:23  iter: 1759  total_loss: 0.1775  loss_cls: 0.02431  loss_box_reg: 0.05997  loss_mask: 0.1001  loss_rpn_cls: 0.0002012  loss_rpn_loc: 0.002385    time: 0.3405  last_time: 0.3565  data_time: 0.0046  last_data_time: 0.0047   lr: 0.00025  max_mem: 2048M
# [07/29 19:18:46 d2.utils.events]:  eta: 0:01:17  iter: 1779  total_loss: 0.1796  loss_cls: 0.02444  loss_box_reg: 0.05919  loss_mask: 0.09215  loss_rpn_cls: 0.0002852  loss_rpn_loc: 0.002358    time: 0.3406  last_time: 0.3958  data_time: 0.0046  last_data_time: 0.0046   lr: 0.00025  max_mem: 2048M
# [07/29 19:18:53 d2.utils.events]:  eta: 0:01:10  iter: 1799  total_loss: 0.1487  loss_cls: 0.02008  loss_box_reg: 0.04137  loss_mask: 0.09197  loss_rpn_cls: 0.0002638  loss_rpn_loc: 0.00261    time: 0.3408  last_time: 0.3599  data_time: 0.0050  last_data_time: 0.0082   lr: 0.00025  max_mem: 2048M
# [07/29 19:19:00 d2.utils.events]:  eta: 0:01:03  iter: 1819  total_loss: 0.1693  loss_cls: 0.02479  loss_box_reg: 0.05629  loss_mask: 0.1039  loss_rpn_cls: 0.0001836  loss_rpn_loc: 0.004698    time: 0.3409  last_time: 0.3119  data_time: 0.0052  last_data_time: 0.0035   lr: 0.00025  max_mem: 2048M
# [07/29 19:19:08 d2.utils.events]:  eta: 0:00:56  iter: 1839  total_loss: 0.1638  loss_cls: 0.01984  loss_box_reg: 0.04776  loss_mask: 0.09363  loss_rpn_cls: 0.0005089  loss_rpn_loc: 0.00378    time: 0.3411  last_time: 0.3865  data_time: 0.0048  last_data_time: 0.0049   lr: 0.00025  max_mem: 2048M
# [07/29 19:19:15 d2.utils.events]:  eta: 0:00:49  iter: 1859  total_loss: 0.2731  loss_cls: 0.02983  loss_box_reg: 0.07598  loss_mask: 0.09442  loss_rpn_cls: 0.0004674  loss_rpn_loc: 0.02844    time: 0.3412  last_time: 0.4035  data_time: 0.0049  last_data_time: 0.0046   lr: 0.00025  max_mem: 2048M
# [07/29 19:19:21 d2.utils.events]:  eta: 0:00:42  iter: 1879  total_loss: 0.1441  loss_cls: 0.01939  loss_box_reg: 0.0443  loss_mask: 0.08505  loss_rpn_cls: 0.0001085  loss_rpn_loc: 0.002615    time: 0.3412  last_time: 0.3269  data_time: 0.0046  last_data_time: 0.0035   lr: 0.00025  max_mem: 2048M
# [07/29 19:19:28 d2.utils.events]:  eta: 0:00:35  iter: 1899  total_loss: 0.1533  loss_cls: 0.02035  loss_box_reg: 0.0461  loss_mask: 0.08649  loss_rpn_cls: 5.73e-05  loss_rpn_loc: 0.003466    time: 0.3413  last_time: 0.3966  data_time: 0.0047  last_data_time: 0.0046   lr: 0.00025  max_mem: 2048M
# [07/29 19:19:35 d2.utils.events]:  eta: 0:00:28  iter: 1919  total_loss: 0.1581  loss_cls: 0.01952  loss_box_reg: 0.06062  loss_mask: 0.08217  loss_rpn_cls: 0.0001884  loss_rpn_loc: 0.002308    time: 0.3413  last_time: 0.3107  data_time: 0.0044  last_data_time: 0.0031   lr: 0.00025  max_mem: 2048M
# [07/29 19:19:42 d2.utils.events]:  eta: 0:00:21  iter: 1939  total_loss: 0.1555  loss_cls: 0.01878  loss_box_reg: 0.05435  loss_mask: 0.08624  loss_rpn_cls: 0.0004776  loss_rpn_loc: 0.003036    time: 0.3414  last_time: 0.3984  data_time: 0.0054  last_data_time: 0.0051   lr: 0.00025  max_mem: 2048M
# [07/29 19:19:49 d2.utils.events]:  eta: 0:00:14  iter: 1959  total_loss: 0.1459  loss_cls: 0.02009  loss_box_reg: 0.04647  loss_mask: 0.08626  loss_rpn_cls: 0.0004275  loss_rpn_loc: 0.00408    time: 0.3415  last_time: 0.2986  data_time: 0.0059  last_data_time: 0.0043   lr: 0.00025  max_mem: 2048M
# [07/29 19:19:56 d2.utils.events]:  eta: 0:00:07  iter: 1979  total_loss: 0.1448  loss_cls: 0.02436  loss_box_reg: 0.04749  loss_mask: 0.07694  loss_rpn_cls: 0.0001597  loss_rpn_loc: 0.00255    time: 0.3415  last_time: 0.3672  data_time: 0.0046  last_data_time: 0.0047   lr: 0.00025  max_mem: 2048M
# [07/29 19:20:04 d2.utils.events]:  eta: 0:00:00  iter: 1999  total_loss: 0.1509  loss_cls: 0.02444  loss_box_reg: 0.05163  loss_mask: 0.07867  loss_rpn_cls: 0.0002887  loss_rpn_loc: 0.003709    time: 0.3415  last_time: 0.3765  data_time: 0.0052  last_data_time: 0.0044   lr: 0.00025  max_mem: 2048M
# [07/29 19:20:04 d2.engine.hooks]: Overall training speed: 1998 iterations in 0:11:22 (0.3415 s / it)
# [07/29 19:20:04 d2.engine.hooks]: Total training time: 0:11:24 (0:00:01 on hooks)

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set a custom testing threshold
predictor = DefaultPredictor(cfg)
# Out:
# [07/29 19:27:44 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./models/Detectron2_Models_infused/model_final.pth ...

# %%
def display_original_and_prediction_with_annotations(val_dataset_dicts, predictor, val_metadata):
    for d in random.sample(val_dataset_dicts, 1):  # Select number of images for display
        im = cv2.imread(d["file_name"])
        outputs = predictor(im)
        
        # Create a visualizer object for the original image with annotations
        v_gt = Visualizer(im[:, :, ::-1],
                          metadata=val_metadata,
                          scale=0.5
        )
        out_gt = v_gt.draw_dataset_dict(d)
        
        # Create a visualizer object for the predicted image
        v_pred = Visualizer(im[:, :, ::-1],
                            metadata=val_metadata,
                            scale=0.5,
        )
        out_pred = v_pred.draw_instance_predictions(outputs["instances"].to("cpu"))
        
        # Set up subplots
        fig, ax = plt.subplots(1, 2, figsize=(20, 10))
        
        # Display the original image with annotations
        ax[0].imshow(out_gt.get_image()[:, :, ::-1])
        ax[0].set_title('Original Image with Annotations')
        ax[0].axis('off')
        
        # Display the predicted image
        ax[1].imshow(out_pred.get_image()[:, :, ::-1])
        ax[1].set_title('Predicted Image')
        ax[1].axis('off')
        
        plt.show()

# Example usage
display_original_and_prediction_with_annotations(test_dataset_dicts, predictor, test_metadata)

# %%
def save_all_images(val_dataset_dicts, predictor, val_metadata, output_dir):
    
    #create image path if it doesnt exist 
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for i, d in enumerate(val_dataset_dicts):

        im = cv2.imread(d["file_name"])
        outputs = predictor(im)
        
        v_gt = Visualizer(im[:, :, ::-1], metadata=val_metadata, scale=0.5)
        out_gt = v_gt.draw_dataset_dict(d)
        
        v_pred = Visualizer(im[:, :, ::-1], metadata=val_metadata, scale=0.5)
        out_pred = v_pred.draw_instance_predictions(outputs["instances"].to("cpu"))
        
        fig, ax = plt.subplots(1, 2, figsize=(20, 10))
        
        ax[0].imshow(out_gt.get_image()[:, :, ::-1])
        ax[0].set_title('Image with Original Annotations')
        ax[0].axis('off')
        
        # Display the predicted image
        ax[1].imshow(out_pred.get_image()[:, :, ::-1])
        ax[1].set_title('Images with Annotations produced by the model')
        ax[1].axis('off')
        
        fig.savefig(os.path.join(output_dir, f"image_{i}.png"))
        plt.close(fig)

# %%
save_all_images(test_dataset_dicts, predictor, test_metadata, './detectron2/images_infused')

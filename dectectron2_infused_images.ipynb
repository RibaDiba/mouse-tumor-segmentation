# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

import numpy as np
import os, json, cv2, random
import matplotlib.pyplot as plt

from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.utils.visualizer import Visualizer, ColorMode

# %%
from detectron2.data.datasets import register_coco_instances

register_coco_instances("my_dataset_train", {}, "./detectron2/data/coco_json/train/images/train.json", "./detectron2/data/coco_json/train/images/")
register_coco_instances("my_dataset_val", {}, "./detectron2/data/coco_json/val/images/val.json", "./detectron2/data/coco_json/val/images/")
register_coco_instances("my_dataset_test", {}, "./detectron2/data/coco_json/test/images/test.json", "./detectron2/data/coco_json/test/images/")

# %%
train_metadata = MetadataCatalog.get("my_dataset_train")
train_dataset_dicts = DatasetCatalog.get("my_dataset_train")

val_metadata = MetadataCatalog.get("my_dataset_val")
val_dataset_dicts = DatasetCatalog.get("my_dataset_val")

test_metadata = MetadataCatalog.get("my_dataset_test")
test_dataset_dicts = DatasetCatalog.get("my_dataset_test")
# Out:
# WARNING [07/29 14:54:57 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 14:54:57 d2.data.datasets.coco]: Loaded 20 images in COCO format from ./detectron2/data/coco_json/train/images/train.json
# WARNING [07/29 14:54:57 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 14:54:57 d2.data.datasets.coco]: Loaded 5 images in COCO format from ./detectron2/data/coco_json/val/images/val.json
# WARNING [07/29 14:54:57 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 14:54:57 d2.data.datasets.coco]: Loaded 10 images in COCO format from ./detectron2/data/coco_json/test/images/test.json

# %%
for d in random.sample(train_dataset_dicts, 2):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=train_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    plt.imshow(vis.get_image()[:, :, ::-1])
    plt.show()

# %%
from detectron2.engine import DefaultTrainer

cfg = get_cfg()
cfg.OUTPUT_DIR = "./models/Detectron2_Models"
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("my_dataset_train", "my_dataset_val")
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2  # This is the real "batch size" commonly known to deep learning people
cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
cfg.SOLVER.MAX_ITER = 2000    # 1000 iterations seems good enough for this dataset
cfg.SOLVER.STEPS = []        # do not decay learning rate
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 256   # Default is 512, using 256 for this dataset.
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1 
# NOTE: this config means the number of classes, without the background. Do not use num_classes+1 here.

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) #Create an instance of of DefaultTrainer with the given congiguration
trainer.resume_or_load(resume=False) #Load a pretrained model if available (resume training) or start training from scratch if no pretrained model is available
# Out:
# [07/29 14:55:04 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# WARNING [07/29 14:55:05 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 14:55:05 d2.data.datasets.coco]: Loaded 20 images in COCO format from ./detectron2/data/coco_json/train/images/train.json
# WARNING [07/29 14:55:05 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/29 14:55:05 d2.data.datasets.coco]: Loaded 5 images in COCO format from ./detectron2/data/coco_json/val/images/val.json
# [07/29 14:55:05 d2.data.build]: Removed 0 images with no usable annotations. 25 images left.
# [07/29 14:55:05 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   Tumor    | 51           |
# |            |              |
# [07/29 14:55:05 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [07/29 14:55:05 d2.data.build]: Using training sampler TrainingSampler
# [07/29 14:55:05 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/29 14:55:05 d2.data.common]: Serializing 25 elements to byte tensors and concatenating them all ...
# [07/29 14:55:05 d2.data.common]: Serialized dataset takes 0.04 MiB
# [07/29 14:55:05 d2.data.build]: Making batched data loader with batch_size=2
# [07/29 14:55:05 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (2, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (1, 256, 1, 1) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (1,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}

# %%
trainer.train()
# Out:
# [07/29 14:55:18 d2.engine.train_loop]: Starting training from iteration 0
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [07/29 14:55:26 d2.utils.events]:  eta: 0:10:25  iter: 19  total_loss: 1.76  loss_cls: 0.777  loss_box_reg: 0.09885  loss_mask: 0.6926  loss_rpn_cls: 0.1466  loss_rpn_loc: 0.01549    time: 0.3113  last_time: 0.3450  data_time: 0.0099  last_data_time: 0.0032   lr: 4.9953e-06  max_mem: 1870M
# [07/29 14:55:32 d2.utils.events]:  eta: 0:10:14  iter: 39  total_loss: 1.562  loss_cls: 0.5944  loss_box_reg: 0.1016  loss_mask: 0.6902  loss_rpn_cls: 0.1067  loss_rpn_loc: 0.008729    time: 0.3062  last_time: 0.3446  data_time: 0.0036  last_data_time: 0.0038   lr: 9.9902e-06  max_mem: 1871M
# [07/29 14:55:38 d2.utils.events]:  eta: 0:10:09  iter: 59  total_loss: 1.308  loss_cls: 0.3966  loss_box_reg: 0.1049  loss_mask: 0.6857  loss_rpn_cls: 0.1189  loss_rpn_loc: 0.0198    time: 0.3069  last_time: 0.3140  data_time: 0.0037  last_data_time: 0.0048   lr: 1.4985e-05  max_mem: 1873M
# [07/29 14:55:45 d2.utils.events]:  eta: 0:10:03  iter: 79  total_loss: 1.072  loss_cls: 0.2211  loss_box_reg: 0.05735  loss_mask: 0.6762  loss_rpn_cls: 0.05142  loss_rpn_loc: 0.0127    time: 0.3091  last_time: 0.2777  data_time: 0.0039  last_data_time: 0.0033   lr: 1.998e-05  max_mem: 1873M
# [07/29 14:55:51 d2.utils.events]:  eta: 0:09:55  iter: 99  total_loss: 0.9002  loss_cls: 0.1167  loss_box_reg: 0.01924  loss_mask: 0.6638  loss_rpn_cls: 0.04452  loss_rpn_loc: 0.01588    time: 0.3082  last_time: 0.3334  data_time: 0.0036  last_data_time: 0.0034   lr: 2.4975e-05  max_mem: 1873M
# [07/29 14:55:56 d2.utils.events]:  eta: 0:09:41  iter: 119  total_loss: 0.8307  loss_cls: 0.07098  loss_box_reg: 0.01634  loss_mask: 0.661  loss_rpn_cls: 0.0497  loss_rpn_loc: 0.02219    time: 0.3042  last_time: 0.2807  data_time: 0.0044  last_data_time: 0.0049   lr: 2.997e-05  max_mem: 1873M
# [07/29 14:56:03 d2.utils.events]:  eta: 0:09:40  iter: 139  total_loss: 0.8329  loss_cls: 0.08056  loss_box_reg: 0.03593  loss_mask: 0.6381  loss_rpn_cls: 0.02952  loss_rpn_loc: 0.01241    time: 0.3056  last_time: 0.2698  data_time: 0.0046  last_data_time: 0.0045   lr: 3.4965e-05  max_mem: 1873M
# [07/29 14:56:09 d2.utils.events]:  eta: 0:09:29  iter: 159  total_loss: 0.9205  loss_cls: 0.1179  loss_box_reg: 0.06354  loss_mask: 0.6176  loss_rpn_cls: 0.04047  loss_rpn_loc: 0.02745    time: 0.3049  last_time: 0.3583  data_time: 0.0045  last_data_time: 0.0043   lr: 3.996e-05  max_mem: 1873M
# [07/29 14:56:15 d2.utils.events]:  eta: 0:09:27  iter: 179  total_loss: 0.9584  loss_cls: 0.1442  loss_box_reg: 0.1067  loss_mask: 0.6184  loss_rpn_cls: 0.02828  loss_rpn_loc: 0.02068    time: 0.3057  last_time: 0.3260  data_time: 0.0051  last_data_time: 0.0051   lr: 4.4955e-05  max_mem: 1873M
# [07/29 14:56:21 d2.utils.events]:  eta: 0:09:17  iter: 199  total_loss: 0.922  loss_cls: 0.1176  loss_box_reg: 0.1041  loss_mask: 0.591  loss_rpn_cls: 0.01842  loss_rpn_loc: 0.0123    time: 0.3055  last_time: 0.2919  data_time: 0.0047  last_data_time: 0.0044   lr: 4.995e-05  max_mem: 1873M
# [07/29 14:56:28 d2.utils.events]:  eta: 0:09:16  iter: 219  total_loss: 1.002  loss_cls: 0.1494  loss_box_reg: 0.1446  loss_mask: 0.5992  loss_rpn_cls: 0.01833  loss_rpn_loc: 0.01484    time: 0.3082  last_time: 0.3342  data_time: 0.0048  last_data_time: 0.0056   lr: 5.4945e-05  max_mem: 1873M
# [07/29 14:56:34 d2.utils.events]:  eta: 0:09:12  iter: 239  total_loss: 0.9406  loss_cls: 0.1224  loss_box_reg: 0.1206  loss_mask: 0.5862  loss_rpn_cls: 0.0168  loss_rpn_loc: 0.0128    time: 0.3092  last_time: 0.3281  data_time: 0.0046  last_data_time: 0.0044   lr: 5.994e-05  max_mem: 1873M
# [07/29 14:56:41 d2.utils.events]:  eta: 0:09:07  iter: 259  total_loss: 0.8949  loss_cls: 0.1477  loss_box_reg: 0.1758  loss_mask: 0.5513  loss_rpn_cls: 0.01812  loss_rpn_loc: 0.01339    time: 0.3101  last_time: 0.3433  data_time: 0.0067  last_data_time: 0.0042   lr: 6.4935e-05  max_mem: 1873M
# [07/29 14:56:47 d2.utils.events]:  eta: 0:09:02  iter: 279  total_loss: 0.9877  loss_cls: 0.1437  loss_box_reg: 0.1828  loss_mask: 0.5516  loss_rpn_cls: 0.01839  loss_rpn_loc: 0.01525    time: 0.3111  last_time: 0.2604  data_time: 0.0052  last_data_time: 0.0032   lr: 6.993e-05  max_mem: 1874M
# [07/29 14:56:53 d2.utils.events]:  eta: 0:08:55  iter: 299  total_loss: 0.9926  loss_cls: 0.1453  loss_box_reg: 0.2138  loss_mask: 0.5013  loss_rpn_cls: 0.01671  loss_rpn_loc: 0.01815    time: 0.3107  last_time: 0.3004  data_time: 0.0047  last_data_time: 0.0039   lr: 7.4925e-05  max_mem: 1874M
# [07/29 14:56:59 d2.utils.events]:  eta: 0:08:45  iter: 319  total_loss: 0.9588  loss_cls: 0.1426  loss_box_reg: 0.217  loss_mask: 0.4807  loss_rpn_cls: 0.01731  loss_rpn_loc: 0.01771    time: 0.3104  last_time: 0.3024  data_time: 0.0043  last_data_time: 0.0039   lr: 7.992e-05  max_mem: 1874M
# [07/29 14:57:06 d2.utils.events]:  eta: 0:08:41  iter: 339  total_loss: 0.8681  loss_cls: 0.1434  loss_box_reg: 0.2267  loss_mask: 0.4774  loss_rpn_cls: 0.01098  loss_rpn_loc: 0.01066    time: 0.3115  last_time: 0.3605  data_time: 0.0045  last_data_time: 0.0049   lr: 8.4915e-05  max_mem: 1874M
# [07/29 14:57:12 d2.utils.events]:  eta: 0:08:35  iter: 359  total_loss: 0.9362  loss_cls: 0.1451  loss_box_reg: 0.2251  loss_mask: 0.4639  loss_rpn_cls: 0.0138  loss_rpn_loc: 0.01295    time: 0.3124  last_time: 0.3549  data_time: 0.0050  last_data_time: 0.0039   lr: 8.991e-05  max_mem: 1874M
# [07/29 14:57:19 d2.utils.events]:  eta: 0:08:29  iter: 379  total_loss: 0.9162  loss_cls: 0.1312  loss_box_reg: 0.2033  loss_mask: 0.4385  loss_rpn_cls: 0.01169  loss_rpn_loc: 0.01355    time: 0.3130  last_time: 0.3239  data_time: 0.0056  last_data_time: 0.0045   lr: 9.4905e-05  max_mem: 1874M
# [07/29 14:57:25 d2.utils.events]:  eta: 0:08:23  iter: 399  total_loss: 0.871  loss_cls: 0.1314  loss_box_reg: 0.2557  loss_mask: 0.428  loss_rpn_cls: 0.009697  loss_rpn_loc: 0.01308    time: 0.3134  last_time: 0.3624  data_time: 0.0047  last_data_time: 0.0050   lr: 9.99e-05  max_mem: 1874M
# [07/29 14:57:32 d2.utils.events]:  eta: 0:08:18  iter: 419  total_loss: 0.8492  loss_cls: 0.123  loss_box_reg: 0.247  loss_mask: 0.4172  loss_rpn_cls: 0.01133  loss_rpn_loc: 0.0124    time: 0.3147  last_time: 0.3567  data_time: 0.0051  last_data_time: 0.0031   lr: 0.0001049  max_mem: 1874M
# [07/29 14:57:38 d2.utils.events]:  eta: 0:08:12  iter: 439  total_loss: 0.8518  loss_cls: 0.126  loss_box_reg: 0.2649  loss_mask: 0.3992  loss_rpn_cls: 0.008257  loss_rpn_loc: 0.009826    time: 0.3146  last_time: 0.3315  data_time: 0.0064  last_data_time: 0.0033   lr: 0.00010989  max_mem: 1874M
# [07/29 14:57:45 d2.utils.events]:  eta: 0:08:06  iter: 459  total_loss: 0.9029  loss_cls: 0.1343  loss_box_reg: 0.2603  loss_mask: 0.3991  loss_rpn_cls: 0.006549  loss_rpn_loc: 0.01418    time: 0.3150  last_time: 0.3588  data_time: 0.0061  last_data_time: 0.0037   lr: 0.00011489  max_mem: 1874M
# [07/29 14:57:52 d2.utils.events]:  eta: 0:08:01  iter: 479  total_loss: 0.8806  loss_cls: 0.1205  loss_box_reg: 0.2525  loss_mask: 0.3784  loss_rpn_cls: 0.008631  loss_rpn_loc: 0.008964    time: 0.3161  last_time: 0.3614  data_time: 0.0049  last_data_time: 0.0062   lr: 0.00011988  max_mem: 1874M
# [07/29 14:57:58 d2.utils.events]:  eta: 0:07:54  iter: 499  total_loss: 0.8045  loss_cls: 0.1186  loss_box_reg: 0.2785  loss_mask: 0.36  loss_rpn_cls: 0.004428  loss_rpn_loc: 0.007597    time: 0.3159  last_time: 0.3155  data_time: 0.0044  last_data_time: 0.0051   lr: 0.00012488  max_mem: 1874M
# [07/29 14:58:05 d2.utils.events]:  eta: 0:07:48  iter: 519  total_loss: 0.8245  loss_cls: 0.1217  loss_box_reg: 0.2699  loss_mask: 0.3827  loss_rpn_cls: 0.004805  loss_rpn_loc: 0.01035    time: 0.3168  last_time: 0.3402  data_time: 0.0050  last_data_time: 0.0046   lr: 0.00012987  max_mem: 1874M
# [07/29 14:58:12 d2.utils.events]:  eta: 0:07:44  iter: 539  total_loss: 0.7536  loss_cls: 0.1015  loss_box_reg: 0.2498  loss_mask: 0.3184  loss_rpn_cls: 0.002282  loss_rpn_loc: 0.01024    time: 0.3175  last_time: 0.3063  data_time: 0.0043  last_data_time: 0.0038   lr: 0.00013487  max_mem: 1874M
# [07/29 14:58:18 d2.utils.events]:  eta: 0:07:38  iter: 559  total_loss: 0.6979  loss_cls: 0.09882  loss_box_reg: 0.2393  loss_mask: 0.336  loss_rpn_cls: 0.004853  loss_rpn_loc: 0.006849    time: 0.3180  last_time: 0.3574  data_time: 0.0040  last_data_time: 0.0029   lr: 0.00013986  max_mem: 1874M
# [07/29 14:58:25 d2.utils.events]:  eta: 0:07:32  iter: 579  total_loss: 0.7451  loss_cls: 0.09843  loss_box_reg: 0.237  loss_mask: 0.3443  loss_rpn_cls: 0.004715  loss_rpn_loc: 0.007859    time: 0.3183  last_time: 0.3723  data_time: 0.0037  last_data_time: 0.0049   lr: 0.00014486  max_mem: 1874M
# [07/29 14:58:31 d2.utils.events]:  eta: 0:07:26  iter: 599  total_loss: 0.6843  loss_cls: 0.09157  loss_box_reg: 0.2164  loss_mask: 0.306  loss_rpn_cls: 0.005688  loss_rpn_loc: 0.008023    time: 0.3187  last_time: 0.3052  data_time: 0.0048  last_data_time: 0.0040   lr: 0.00014985  max_mem: 1874M
# [07/29 14:58:38 d2.utils.events]:  eta: 0:07:21  iter: 619  total_loss: 0.6762  loss_cls: 0.08917  loss_box_reg: 0.2158  loss_mask: 0.3032  loss_rpn_cls: 0.005073  loss_rpn_loc: 0.01163    time: 0.3189  last_time: 0.3339  data_time: 0.0050  last_data_time: 0.0034   lr: 0.00015485  max_mem: 1874M
# [07/29 14:58:44 d2.utils.events]:  eta: 0:07:14  iter: 639  total_loss: 0.6427  loss_cls: 0.08636  loss_box_reg: 0.1915  loss_mask: 0.2858  loss_rpn_cls: 0.003322  loss_rpn_loc: 0.008669    time: 0.3189  last_time: 0.3137  data_time: 0.0037  last_data_time: 0.0047   lr: 0.00015984  max_mem: 1874M
# [07/29 14:58:51 d2.utils.events]:  eta: 0:07:09  iter: 659  total_loss: 0.6178  loss_cls: 0.07106  loss_box_reg: 0.1728  loss_mask: 0.2898  loss_rpn_cls: 0.001082  loss_rpn_loc: 0.00614    time: 0.3192  last_time: 0.3676  data_time: 0.0044  last_data_time: 0.0048   lr: 0.00016484  max_mem: 1874M
# [07/29 14:58:58 d2.utils.events]:  eta: 0:07:03  iter: 679  total_loss: 0.514  loss_cls: 0.06347  loss_box_reg: 0.1625  loss_mask: 0.2731  loss_rpn_cls: 0.002699  loss_rpn_loc: 0.004497    time: 0.3198  last_time: 0.3621  data_time: 0.0050  last_data_time: 0.0034   lr: 0.00016983  max_mem: 1874M
# [07/29 14:59:04 d2.utils.events]:  eta: 0:06:56  iter: 699  total_loss: 0.5881  loss_cls: 0.07582  loss_box_reg: 0.1817  loss_mask: 0.2849  loss_rpn_cls: 0.003829  loss_rpn_loc: 0.008463    time: 0.3200  last_time: 0.3174  data_time: 0.0036  last_data_time: 0.0047   lr: 0.00017483  max_mem: 1874M
# [07/29 14:59:11 d2.utils.events]:  eta: 0:06:51  iter: 719  total_loss: 0.5156  loss_cls: 0.05733  loss_box_reg: 0.143  loss_mask: 0.2573  loss_rpn_cls: 0.006689  loss_rpn_loc: 0.006567    time: 0.3205  last_time: 0.3252  data_time: 0.0047  last_data_time: 0.0051   lr: 0.00017982  max_mem: 1874M
# [07/29 14:59:17 d2.utils.events]:  eta: 0:06:44  iter: 739  total_loss: 0.4627  loss_cls: 0.05449  loss_box_reg: 0.123  loss_mask: 0.2497  loss_rpn_cls: 0.001173  loss_rpn_loc: 0.007203    time: 0.3205  last_time: 0.3080  data_time: 0.0049  last_data_time: 0.0033   lr: 0.00018482  max_mem: 1874M
# [07/29 14:59:24 d2.utils.events]:  eta: 0:06:38  iter: 759  total_loss: 0.4417  loss_cls: 0.05585  loss_box_reg: 0.1484  loss_mask: 0.2344  loss_rpn_cls: 0.002327  loss_rpn_loc: 0.008723    time: 0.3207  last_time: 0.3521  data_time: 0.0041  last_data_time: 0.0043   lr: 0.00018981  max_mem: 1874M
# [07/29 14:59:31 d2.utils.events]:  eta: 0:06:32  iter: 779  total_loss: 0.4615  loss_cls: 0.05267  loss_box_reg: 0.1414  loss_mask: 0.22  loss_rpn_cls: 0.000879  loss_rpn_loc: 0.006629    time: 0.3211  last_time: 0.3113  data_time: 0.0045  last_data_time: 0.0049   lr: 0.00019481  max_mem: 1874M
# [07/29 14:59:37 d2.utils.events]:  eta: 0:06:25  iter: 799  total_loss: 0.435  loss_cls: 0.06139  loss_box_reg: 0.1138  loss_mask: 0.2069  loss_rpn_cls: 0.001448  loss_rpn_loc: 0.00578    time: 0.3215  last_time: 0.2643  data_time: 0.0045  last_data_time: 0.0031   lr: 0.0001998  max_mem: 1874M
# [07/29 14:59:44 d2.utils.events]:  eta: 0:06:19  iter: 819  total_loss: 0.359  loss_cls: 0.04794  loss_box_reg: 0.09935  loss_mask: 0.1976  loss_rpn_cls: 0.002226  loss_rpn_loc: 0.0086    time: 0.3217  last_time: 0.2644  data_time: 0.0039  last_data_time: 0.0048   lr: 0.0002048  max_mem: 1874M
# [07/29 14:59:51 d2.utils.events]:  eta: 0:06:14  iter: 839  total_loss: 0.3554  loss_cls: 0.04411  loss_box_reg: 0.1045  loss_mask: 0.2105  loss_rpn_cls: 0.0005891  loss_rpn_loc: 0.004549    time: 0.3222  last_time: 0.3859  data_time: 0.0057  last_data_time: 0.0043   lr: 0.00020979  max_mem: 1874M
# [07/29 14:59:57 d2.utils.events]:  eta: 0:06:08  iter: 859  total_loss: 0.3764  loss_cls: 0.04752  loss_box_reg: 0.1199  loss_mask: 0.1924  loss_rpn_cls: 0.0004076  loss_rpn_loc: 0.005632    time: 0.3224  last_time: 0.3024  data_time: 0.0045  last_data_time: 0.0032   lr: 0.00021479  max_mem: 1874M
# [07/29 15:00:04 d2.utils.events]:  eta: 0:06:01  iter: 879  total_loss: 0.3523  loss_cls: 0.03687  loss_box_reg: 0.112  loss_mask: 0.1873  loss_rpn_cls: 0.002656  loss_rpn_loc: 0.00497    time: 0.3225  last_time: 0.2942  data_time: 0.0038  last_data_time: 0.0049   lr: 0.00021978  max_mem: 1874M
# [07/29 15:00:11 d2.utils.events]:  eta: 0:05:55  iter: 899  total_loss: 0.3601  loss_cls: 0.04094  loss_box_reg: 0.09839  loss_mask: 0.1935  loss_rpn_cls: 0.001046  loss_rpn_loc: 0.01206    time: 0.3229  last_time: 0.3994  data_time: 0.0056  last_data_time: 0.0047   lr: 0.00022478  max_mem: 1874M
# [07/29 15:00:17 d2.utils.events]:  eta: 0:05:48  iter: 919  total_loss: 0.3398  loss_cls: 0.04717  loss_box_reg: 0.09064  loss_mask: 0.1953  loss_rpn_cls: 0.004953  loss_rpn_loc: 0.004495    time: 0.3230  last_time: 0.2886  data_time: 0.0042  last_data_time: 0.0033   lr: 0.00022977  max_mem: 1874M
# [07/29 15:00:24 d2.utils.events]:  eta: 0:05:42  iter: 939  total_loss: 0.4428  loss_cls: 0.05372  loss_box_reg: 0.1064  loss_mask: 0.1844  loss_rpn_cls: 0.001155  loss_rpn_loc: 0.04287    time: 0.3234  last_time: 0.3585  data_time: 0.0036  last_data_time: 0.0048   lr: 0.00023477  max_mem: 1874M
# [07/29 15:00:31 d2.utils.events]:  eta: 0:05:36  iter: 959  total_loss: 0.3017  loss_cls: 0.04119  loss_box_reg: 0.09412  loss_mask: 0.1619  loss_rpn_cls: 0.0002559  loss_rpn_loc: 0.004441    time: 0.3238  last_time: 0.3822  data_time: 0.0045  last_data_time: 0.0046   lr: 0.00023976  max_mem: 1874M
# [07/29 15:00:38 d2.utils.events]:  eta: 0:05:30  iter: 979  total_loss: 0.3604  loss_cls: 0.04432  loss_box_reg: 0.1005  loss_mask: 0.1875  loss_rpn_cls: 0.0007606  loss_rpn_loc: 0.00734    time: 0.3240  last_time: 0.3539  data_time: 0.0045  last_data_time: 0.0046   lr: 0.00024476  max_mem: 1874M
# [07/29 15:00:45 d2.utils.events]:  eta: 0:05:23  iter: 999  total_loss: 0.2908  loss_cls: 0.03337  loss_box_reg: 0.07888  loss_mask: 0.163  loss_rpn_cls: 0.0001854  loss_rpn_loc: 0.003289    time: 0.3243  last_time: 0.3430  data_time: 0.0054  last_data_time: 0.0106   lr: 0.00024975  max_mem: 1874M
# [07/29 15:00:51 d2.utils.events]:  eta: 0:05:17  iter: 1019  total_loss: 0.3073  loss_cls: 0.03002  loss_box_reg: 0.0808  loss_mask: 0.1574  loss_rpn_cls: 0.0001786  loss_rpn_loc: 0.003378    time: 0.3244  last_time: 0.3030  data_time: 0.0045  last_data_time: 0.0051   lr: 0.00025  max_mem: 1874M
# [07/29 15:00:58 d2.utils.events]:  eta: 0:05:12  iter: 1039  total_loss: 0.297  loss_cls: 0.03618  loss_box_reg: 0.08574  loss_mask: 0.1601  loss_rpn_cls: 8.008e-05  loss_rpn_loc: 0.003274    time: 0.3246  last_time: 0.2882  data_time: 0.0046  last_data_time: 0.0052   lr: 0.00025  max_mem: 1874M
# [07/29 15:01:05 d2.utils.events]:  eta: 0:05:06  iter: 1059  total_loss: 0.2782  loss_cls: 0.03786  loss_box_reg: 0.08009  loss_mask: 0.152  loss_rpn_cls: 0.0004656  loss_rpn_loc: 0.004581    time: 0.3249  last_time: 0.2891  data_time: 0.0052  last_data_time: 0.0045   lr: 0.00025  max_mem: 1874M
# [07/29 15:01:11 d2.utils.events]:  eta: 0:05:00  iter: 1079  total_loss: 0.2974  loss_cls: 0.03115  loss_box_reg: 0.08669  loss_mask: 0.1839  loss_rpn_cls: 0.0003368  loss_rpn_loc: 0.004439    time: 0.3250  last_time: 0.3204  data_time: 0.0044  last_data_time: 0.0045   lr: 0.00025  max_mem: 1874M
# [07/29 15:01:18 d2.utils.events]:  eta: 0:04:55  iter: 1099  total_loss: 0.2959  loss_cls: 0.04246  loss_box_reg: 0.1005  loss_mask: 0.161  loss_rpn_cls: 0.001937  loss_rpn_loc: 0.004018    time: 0.3253  last_time: 0.2932  data_time: 0.0043  last_data_time: 0.0046   lr: 0.00025  max_mem: 1874M
# [07/29 15:01:25 d2.utils.events]:  eta: 0:04:50  iter: 1119  total_loss: 0.2647  loss_cls: 0.03617  loss_box_reg: 0.08017  loss_mask: 0.1413  loss_rpn_cls: 0.001932  loss_rpn_loc: 0.004672    time: 0.3256  last_time: 0.3534  data_time: 0.0044  last_data_time: 0.0041   lr: 0.00025  max_mem: 1874M
# [07/29 15:01:32 d2.utils.events]:  eta: 0:04:44  iter: 1139  total_loss: 0.2504  loss_cls: 0.03378  loss_box_reg: 0.07379  loss_mask: 0.1452  loss_rpn_cls: 0.0005215  loss_rpn_loc: 0.004565    time: 0.3256  last_time: 0.2768  data_time: 0.0047  last_data_time: 0.0032   lr: 0.00025  max_mem: 1874M
# [07/29 15:01:38 d2.utils.events]:  eta: 0:04:37  iter: 1159  total_loss: 0.2351  loss_cls: 0.03102  loss_box_reg: 0.06397  loss_mask: 0.1418  loss_rpn_cls: 0.0001276  loss_rpn_loc: 0.005453    time: 0.3258  last_time: 0.2964  data_time: 0.0045  last_data_time: 0.0052   lr: 0.00025  max_mem: 1874M
# [07/29 15:01:45 d2.utils.events]:  eta: 0:04:31  iter: 1179  total_loss: 0.2083  loss_cls: 0.02783  loss_box_reg: 0.07006  loss_mask: 0.1239  loss_rpn_cls: 0.0001668  loss_rpn_loc: 0.002923    time: 0.3259  last_time: 0.3134  data_time: 0.0050  last_data_time: 0.0054   lr: 0.00025  max_mem: 1874M
# [07/29 15:01:52 d2.utils.events]:  eta: 0:04:26  iter: 1199  total_loss: 0.232  loss_cls: 0.0344  loss_box_reg: 0.07209  loss_mask: 0.1262  loss_rpn_cls: 0.001242  loss_rpn_loc: 0.003283    time: 0.3262  last_time: 0.3664  data_time: 0.0046  last_data_time: 0.0036   lr: 0.00025  max_mem: 1874M
# [07/29 15:01:58 d2.utils.events]:  eta: 0:04:19  iter: 1219  total_loss: 0.2101  loss_cls: 0.02758  loss_box_reg: 0.0618  loss_mask: 0.1362  loss_rpn_cls: 3.882e-05  loss_rpn_loc: 0.002572    time: 0.3262  last_time: 0.2946  data_time: 0.0044  last_data_time: 0.0053   lr: 0.00025  max_mem: 1874M
# [07/29 15:02:05 d2.utils.events]:  eta: 0:04:12  iter: 1239  total_loss: 0.2424  loss_cls: 0.02836  loss_box_reg: 0.06786  loss_mask: 0.1384  loss_rpn_cls: 0.0001205  loss_rpn_loc: 0.003583    time: 0.3264  last_time: 0.3599  data_time: 0.0045  last_data_time: 0.0036   lr: 0.00025  max_mem: 1874M
# [07/29 15:02:12 d2.utils.events]:  eta: 0:04:06  iter: 1259  total_loss: 0.2166  loss_cls: 0.02615  loss_box_reg: 0.06175  loss_mask: 0.121  loss_rpn_cls: 0.0003476  loss_rpn_loc: 0.006095    time: 0.3265  last_time: 0.2901  data_time: 0.0052  last_data_time: 0.0034   lr: 0.00025  max_mem: 1874M
# [07/29 15:02:18 d2.utils.events]:  eta: 0:04:00  iter: 1279  total_loss: 0.2853  loss_cls: 0.03375  loss_box_reg: 0.06732  loss_mask: 0.1348  loss_rpn_cls: 0.0007571  loss_rpn_loc: 0.00534    time: 0.3266  last_time: 0.2996  data_time: 0.0043  last_data_time: 0.0038   lr: 0.00025  max_mem: 1874M
# [07/29 15:02:25 d2.utils.events]:  eta: 0:03:54  iter: 1299  total_loss: 0.2324  loss_cls: 0.03444  loss_box_reg: 0.07195  loss_mask: 0.1189  loss_rpn_cls: 0.000166  loss_rpn_loc: 0.006326    time: 0.3269  last_time: 0.3544  data_time: 0.0049  last_data_time: 0.0107   lr: 0.00025  max_mem: 1874M
# [07/29 15:02:32 d2.utils.events]:  eta: 0:03:48  iter: 1319  total_loss: 0.2752  loss_cls: 0.0352  loss_box_reg: 0.07929  loss_mask: 0.1345  loss_rpn_cls: 0.0001248  loss_rpn_loc: 0.004735    time: 0.3272  last_time: 0.2847  data_time: 0.0054  last_data_time: 0.0034   lr: 0.00025  max_mem: 1874M
# [07/29 15:02:39 d2.utils.events]:  eta: 0:03:41  iter: 1339  total_loss: 0.2045  loss_cls: 0.02934  loss_box_reg: 0.06058  loss_mask: 0.1173  loss_rpn_cls: 0.0001488  loss_rpn_loc: 0.003354    time: 0.3275  last_time: 0.3450  data_time: 0.0065  last_data_time: 0.0052   lr: 0.00025  max_mem: 1874M
# [07/29 15:02:46 d2.utils.events]:  eta: 0:03:35  iter: 1359  total_loss: 0.2135  loss_cls: 0.02445  loss_box_reg: 0.05465  loss_mask: 0.1219  loss_rpn_cls: 0.0001866  loss_rpn_loc: 0.002971    time: 0.3277  last_time: 0.3540  data_time: 0.0051  last_data_time: 0.0049   lr: 0.00025  max_mem: 1874M
# [07/29 15:02:53 d2.utils.events]:  eta: 0:03:28  iter: 1379  total_loss: 0.2189  loss_cls: 0.02507  loss_box_reg: 0.06485  loss_mask: 0.1169  loss_rpn_cls: 0.0001086  loss_rpn_loc: 0.004549    time: 0.3278  last_time: 0.3784  data_time: 0.0043  last_data_time: 0.0048   lr: 0.00025  max_mem: 1874M
# [07/29 15:03:00 d2.utils.events]:  eta: 0:03:22  iter: 1399  total_loss: 0.2059  loss_cls: 0.02986  loss_box_reg: 0.05265  loss_mask: 0.1228  loss_rpn_cls: 0.0001096  loss_rpn_loc: 0.003254    time: 0.3280  last_time: 0.3437  data_time: 0.0052  last_data_time: 0.0048   lr: 0.00025  max_mem: 1874M
# [07/29 15:03:07 d2.utils.events]:  eta: 0:03:15  iter: 1419  total_loss: 0.1941  loss_cls: 0.02525  loss_box_reg: 0.05023  loss_mask: 0.1133  loss_rpn_cls: 8.438e-05  loss_rpn_loc: 0.00318    time: 0.3282  last_time: 0.3085  data_time: 0.0044  last_data_time: 0.0045   lr: 0.00025  max_mem: 1874M
# [07/29 15:03:13 d2.utils.events]:  eta: 0:03:09  iter: 1439  total_loss: 0.1756  loss_cls: 0.02448  loss_box_reg: 0.05228  loss_mask: 0.1054  loss_rpn_cls: 0.0004531  loss_rpn_loc: 0.004742    time: 0.3283  last_time: 0.3454  data_time: 0.0043  last_data_time: 0.0046   lr: 0.00025  max_mem: 1874M
# [07/29 15:03:20 d2.utils.events]:  eta: 0:03:03  iter: 1459  total_loss: 0.1724  loss_cls: 0.02964  loss_box_reg: 0.04839  loss_mask: 0.09932  loss_rpn_cls: 0.0001414  loss_rpn_loc: 0.003061    time: 0.3287  last_time: 0.3847  data_time: 0.0058  last_data_time: 0.0047   lr: 0.00025  max_mem: 1874M
# [07/29 15:03:27 d2.utils.events]:  eta: 0:02:56  iter: 1479  total_loss: 0.1867  loss_cls: 0.03055  loss_box_reg: 0.05635  loss_mask: 0.1034  loss_rpn_cls: 6.875e-05  loss_rpn_loc: 0.003673    time: 0.3287  last_time: 0.3404  data_time: 0.0043  last_data_time: 0.0030   lr: 0.00025  max_mem: 1874M
# [07/29 15:03:34 d2.utils.events]:  eta: 0:02:50  iter: 1499  total_loss: 0.1817  loss_cls: 0.02237  loss_box_reg: 0.05388  loss_mask: 0.1063  loss_rpn_cls: 2.882e-05  loss_rpn_loc: 0.002531    time: 0.3289  last_time: 0.2959  data_time: 0.0055  last_data_time: 0.0050   lr: 0.00025  max_mem: 1874M
# [07/29 15:03:41 d2.utils.events]:  eta: 0:02:43  iter: 1519  total_loss: 0.178  loss_cls: 0.02092  loss_box_reg: 0.05538  loss_mask: 0.1073  loss_rpn_cls: 0.000112  loss_rpn_loc: 0.002647    time: 0.3291  last_time: 0.3176  data_time: 0.0051  last_data_time: 0.0035   lr: 0.00025  max_mem: 1874M
# [07/29 15:03:48 d2.utils.events]:  eta: 0:02:36  iter: 1539  total_loss: 0.1682  loss_cls: 0.02963  loss_box_reg: 0.05207  loss_mask: 0.1044  loss_rpn_cls: 0.0001341  loss_rpn_loc: 0.003734    time: 0.3292  last_time: 0.3725  data_time: 0.0050  last_data_time: 0.0037   lr: 0.00025  max_mem: 1874M
# [07/29 15:03:54 d2.utils.events]:  eta: 0:02:29  iter: 1559  total_loss: 0.2047  loss_cls: 0.03278  loss_box_reg: 0.05076  loss_mask: 0.108  loss_rpn_cls: 0.0004974  loss_rpn_loc: 0.003754    time: 0.3294  last_time: 0.3545  data_time: 0.0054  last_data_time: 0.0049   lr: 0.00025  max_mem: 1874M
# [07/29 15:04:01 d2.utils.events]:  eta: 0:02:22  iter: 1579  total_loss: 0.1725  loss_cls: 0.02528  loss_box_reg: 0.05199  loss_mask: 0.09428  loss_rpn_cls: 6.497e-05  loss_rpn_loc: 0.003368    time: 0.3295  last_time: 0.3330  data_time: 0.0055  last_data_time: 0.0062   lr: 0.00025  max_mem: 1874M
# [07/29 15:04:08 d2.utils.events]:  eta: 0:02:16  iter: 1599  total_loss: 0.1655  loss_cls: 0.01888  loss_box_reg: 0.05009  loss_mask: 0.09811  loss_rpn_cls: 5.974e-05  loss_rpn_loc: 0.003548    time: 0.3296  last_time: 0.3229  data_time: 0.0045  last_data_time: 0.0047   lr: 0.00025  max_mem: 1874M
# [07/29 15:04:15 d2.utils.events]:  eta: 0:02:09  iter: 1619  total_loss: 0.2063  loss_cls: 0.03036  loss_box_reg: 0.06055  loss_mask: 0.1088  loss_rpn_cls: 0.0003763  loss_rpn_loc: 0.003463    time: 0.3297  last_time: 0.3185  data_time: 0.0044  last_data_time: 0.0042   lr: 0.00025  max_mem: 1874M
# [07/29 15:04:21 d2.utils.events]:  eta: 0:02:02  iter: 1639  total_loss: 0.1661  loss_cls: 0.02381  loss_box_reg: 0.04809  loss_mask: 0.09254  loss_rpn_cls: 0.0001421  loss_rpn_loc: 0.003342    time: 0.3298  last_time: 0.3121  data_time: 0.0046  last_data_time: 0.0037   lr: 0.00025  max_mem: 1874M
# [07/29 15:04:28 d2.utils.events]:  eta: 0:01:56  iter: 1659  total_loss: 0.2028  loss_cls: 0.02802  loss_box_reg: 0.05273  loss_mask: 0.1165  loss_rpn_cls: 0.0002495  loss_rpn_loc: 0.003891    time: 0.3299  last_time: 0.2763  data_time: 0.0042  last_data_time: 0.0039   lr: 0.00025  max_mem: 1874M
# [07/29 15:04:35 d2.utils.events]:  eta: 0:01:49  iter: 1679  total_loss: 0.1706  loss_cls: 0.02667  loss_box_reg: 0.05218  loss_mask: 0.1141  loss_rpn_cls: 0.0002462  loss_rpn_loc: 0.003362    time: 0.3299  last_time: 0.3362  data_time: 0.0041  last_data_time: 0.0084   lr: 0.00025  max_mem: 1874M
# [07/29 15:04:42 d2.utils.events]:  eta: 0:01:42  iter: 1699  total_loss: 0.1801  loss_cls: 0.02322  loss_box_reg: 0.05139  loss_mask: 0.09602  loss_rpn_cls: 0.0001198  loss_rpn_loc: 0.001961    time: 0.3300  last_time: 0.3090  data_time: 0.0047  last_data_time: 0.0032   lr: 0.00025  max_mem: 1874M
# [07/29 15:04:48 d2.utils.events]:  eta: 0:01:35  iter: 1719  total_loss: 0.1503  loss_cls: 0.01555  loss_box_reg: 0.03922  loss_mask: 0.09643  loss_rpn_cls: 0.0001626  loss_rpn_loc: 0.002554    time: 0.3300  last_time: 0.3658  data_time: 0.0055  last_data_time: 0.0032   lr: 0.00025  max_mem: 1874M
# [07/29 15:04:55 d2.utils.events]:  eta: 0:01:29  iter: 1739  total_loss: 0.2499  loss_cls: 0.02388  loss_box_reg: 0.05852  loss_mask: 0.1111  loss_rpn_cls: 0.0003555  loss_rpn_loc: 0.01241    time: 0.3301  last_time: 0.2915  data_time: 0.0038  last_data_time: 0.0038   lr: 0.00025  max_mem: 1874M
# [07/29 15:05:02 d2.utils.events]:  eta: 0:01:22  iter: 1759  total_loss: 0.153  loss_cls: 0.02302  loss_box_reg: 0.04292  loss_mask: 0.08893  loss_rpn_cls: 0.0001664  loss_rpn_loc: 0.0029    time: 0.3302  last_time: 0.3285  data_time: 0.0047  last_data_time: 0.0030   lr: 0.00025  max_mem: 1874M
# [07/29 15:05:08 d2.utils.events]:  eta: 0:01:15  iter: 1779  total_loss: 0.1705  loss_cls: 0.02663  loss_box_reg: 0.04269  loss_mask: 0.09093  loss_rpn_cls: 0.0004969  loss_rpn_loc: 0.004364    time: 0.3302  last_time: 0.3077  data_time: 0.0045  last_data_time: 0.0040   lr: 0.00025  max_mem: 1874M
# [07/29 15:05:15 d2.utils.events]:  eta: 0:01:08  iter: 1799  total_loss: 0.1627  loss_cls: 0.02094  loss_box_reg: 0.04663  loss_mask: 0.09223  loss_rpn_cls: 0.0001092  loss_rpn_loc: 0.003563    time: 0.3303  last_time: 0.2997  data_time: 0.0050  last_data_time: 0.0036   lr: 0.00025  max_mem: 1874M
# [07/29 15:05:22 d2.utils.events]:  eta: 0:01:01  iter: 1819  total_loss: 0.1961  loss_cls: 0.02272  loss_box_reg: 0.06694  loss_mask: 0.1013  loss_rpn_cls: 0.0001021  loss_rpn_loc: 0.002342    time: 0.3303  last_time: 0.3100  data_time: 0.0048  last_data_time: 0.0033   lr: 0.00025  max_mem: 1874M
# [07/29 15:05:29 d2.utils.events]:  eta: 0:00:54  iter: 1839  total_loss: 0.1477  loss_cls: 0.02009  loss_box_reg: 0.05083  loss_mask: 0.07975  loss_rpn_cls: 0.000179  loss_rpn_loc: 0.003158    time: 0.3304  last_time: 0.3456  data_time: 0.0045  last_data_time: 0.0033   lr: 0.00025  max_mem: 1874M
# [07/29 15:05:35 d2.utils.events]:  eta: 0:00:47  iter: 1859  total_loss: 0.1512  loss_cls: 0.02069  loss_box_reg: 0.04085  loss_mask: 0.08759  loss_rpn_cls: 8.849e-05  loss_rpn_loc: 0.002444    time: 0.3305  last_time: 0.3233  data_time: 0.0053  last_data_time: 0.0053   lr: 0.00025  max_mem: 1874M
# [07/29 15:05:42 d2.utils.events]:  eta: 0:00:41  iter: 1879  total_loss: 0.1832  loss_cls: 0.02622  loss_box_reg: 0.06404  loss_mask: 0.0955  loss_rpn_cls: 0.000139  loss_rpn_loc: 0.00614    time: 0.3306  last_time: 0.3571  data_time: 0.0046  last_data_time: 0.0033   lr: 0.00025  max_mem: 1874M
# [07/29 15:05:49 d2.utils.events]:  eta: 0:00:34  iter: 1899  total_loss: 0.1357  loss_cls: 0.01768  loss_box_reg: 0.04056  loss_mask: 0.07719  loss_rpn_cls: 0.0001172  loss_rpn_loc: 0.00352    time: 0.3306  last_time: 0.2968  data_time: 0.0049  last_data_time: 0.0048   lr: 0.00025  max_mem: 1874M
# [07/29 15:05:56 d2.utils.events]:  eta: 0:00:27  iter: 1919  total_loss: 0.1499  loss_cls: 0.01629  loss_box_reg: 0.03963  loss_mask: 0.09093  loss_rpn_cls: 0.0002738  loss_rpn_loc: 0.00294    time: 0.3308  last_time: 0.3748  data_time: 0.0046  last_data_time: 0.0042   lr: 0.00025  max_mem: 1874M
# [07/29 15:06:03 d2.utils.events]:  eta: 0:00:20  iter: 1939  total_loss: 0.1413  loss_cls: 0.01817  loss_box_reg: 0.04189  loss_mask: 0.08489  loss_rpn_cls: 7.19e-05  loss_rpn_loc: 0.00218    time: 0.3310  last_time: 0.3516  data_time: 0.0043  last_data_time: 0.0053   lr: 0.00025  max_mem: 1874M
# [07/29 15:06:10 d2.utils.events]:  eta: 0:00:13  iter: 1959  total_loss: 0.1681  loss_cls: 0.0213  loss_box_reg: 0.05231  loss_mask: 0.08147  loss_rpn_cls: 0.0001158  loss_rpn_loc: 0.002819    time: 0.3311  last_time: 0.3548  data_time: 0.0054  last_data_time: 0.0044   lr: 0.00025  max_mem: 1874M
# [07/29 15:06:17 d2.utils.events]:  eta: 0:00:06  iter: 1979  total_loss: 0.1543  loss_cls: 0.02018  loss_box_reg: 0.04939  loss_mask: 0.08178  loss_rpn_cls: 5.357e-05  loss_rpn_loc: 0.0026    time: 0.3312  last_time: 0.2910  data_time: 0.0056  last_data_time: 0.0036   lr: 0.00025  max_mem: 1874M
# [07/29 15:06:25 d2.utils.events]:  eta: 0:00:00  iter: 1999  total_loss: 0.1561  loss_cls: 0.02711  loss_box_reg: 0.0506  loss_mask: 0.08378  loss_rpn_cls: 0.0001158  loss_rpn_loc: 0.002236    time: 0.3313  last_time: 0.3434  data_time: 0.0044  last_data_time: 0.0049   lr: 0.00025  max_mem: 1874M
# [07/29 15:06:25 d2.engine.hooks]: Overall training speed: 1998 iterations in 0:11:01 (0.3313 s / it)
# [07/29 15:06:25 d2.engine.hooks]: Total training time: 0:11:04 (0:00:02 on hooks)

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5   # set a custom testing threshold
predictor = DefaultPredictor(cfg)
# Out:
# [07/29 15:08:12 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./models/Detectron2_Models/model_final.pth ...

# %%
def display_original_and_prediction_with_annotations(val_dataset_dicts, predictor, val_metadata):
    for d in random.sample(val_dataset_dicts, 1):  # Select number of images for display
        im = cv2.imread(d["file_name"])
        outputs = predictor(im)
        
        # Create a visualizer object for the original image with annotations
        v_gt = Visualizer(im[:, :, ::-1],
                          metadata=val_metadata,
                          scale=0.5
        )
        out_gt = v_gt.draw_dataset_dict(d)
        
        # Create a visualizer object for the predicted image
        v_pred = Visualizer(im[:, :, ::-1],
                            metadata=val_metadata,
                            scale=0.5,
        )
        out_pred = v_pred.draw_instance_predictions(outputs["instances"].to("cpu"))
        
        # Set up subplots
        fig, ax = plt.subplots(1, 2, figsize=(20, 10))
        
        # Display the original image with annotations
        ax[0].imshow(out_gt.get_image()[:, :, ::-1])
        ax[0].set_title('Original Image with Annotations')
        ax[0].axis('off')
        
        # Display the predicted image
        ax[1].imshow(out_pred.get_image()[:, :, ::-1])
        ax[1].set_title('Predicted Image')
        ax[1].axis('off')
        
        plt.show()

# Example usage
display_original_and_prediction_with_annotations(test_dataset_dicts, predictor, test_metadata)

# %%
def save_all_images(val_dataset_dicts, predictor, val_metadata, output_dir):
    
    #create image path if it doesnt exist 
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for i, d in enumerate(val_dataset_dicts):

        im = cv2.imread(d["file_name"])
        outputs = predictor(im)
        
        v_gt = Visualizer(im[:, :, ::-1], metadata=val_metadata, scale=0.5)
        out_gt = v_gt.draw_dataset_dict(d)
        
        v_pred = Visualizer(im[:, :, ::-1], metadata=val_metadata, scale=0.5)
        out_pred = v_pred.draw_instance_predictions(outputs["instances"].to("cpu"))
        
        fig, ax = plt.subplots(1, 2, figsize=(20, 10))
        
        ax[0].imshow(out_gt.get_image()[:, :, ::-1])
        ax[0].set_title('Image with Original Annotations')
        ax[0].axis('off')
        
        # Display the predicted image
        ax[1].imshow(out_pred.get_image()[:, :, ::-1])
        ax[1].set_title('Images with Annotations produced by the model')
        ax[1].axis('off')
        
        fig.savefig(os.path.join(output_dir, f"image_{i}.png"))
        plt.close(fig)

# %%
save_all_images(test_dataset_dicts, predictor, test_metadata, './detectron2/images_infused')
